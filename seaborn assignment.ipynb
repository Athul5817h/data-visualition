# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
#1. Create a scatter plot to visualize the relationship between two variables, by generating a syntheticdataset.

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
df = sns.load_dataset('flights')

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.relplot(x = 'year' , y = 'passengers' , hue = "month", data = df)
plt.title("filghts")
plt.show()

# %%
#2. Generate a dataset of random numbers. Visualize the distribution of a numerical variable.

sns.relplot(x = np.random.rand(100), y = np.random.rand(100),kind = "line",label = "random")
plt.title("dataset of random numbers")
plt.xlabel("X")
plt.ylabel("Y")
plt.legend()
plt.show()

# %%
#3  Create a dataset representing categories and their corresponding values. Compare different categories based on numerical values.

# %%
sns.catplot(x = ["A","B","C","D"], y =[1,2,3,4])
plt.title("categories and their corresponding values")
plt.xlabel("categories")
plt.ylabel("Values")
plt.show()

# %%
#4. Generate a dataset with categories and numerical values. Visualize the distribution of a numerical variable across different categories.

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.catplot( x = df["month"] , y = df.passengers , hue = df.year, kind = "swarm")
plt.title("categories and numerical values")
plt.show()

# %%
#5. Generate a synthetic dataset with correlated features. Visualize the correlation matrix of a dataset using aheatmap.

# %%
ds = sns.load_dataset('tips')

# %%
ds1 = ds[["tip","total_bill","size"]]
ds1
# Out:
#       tip  total_bill  size
# 0    1.01       16.99     2
# 1    1.66       10.34     3
# 2    3.50       21.01     3
# 3    3.31       23.68     2
# 4    3.61       24.59     4
# ..    ...         ...   ...
# 239  5.92       29.03     3
# 240  2.00       27.18     2
# 241  2.00       22.67     2
# 242  1.75       17.82     2
# 243  3.00       18.78     2
#
# [244 rows x 3 columns]

# %%
sns.heatmap(ds1.corr(),cmap = "coolwarm",annot = True)
plt.title("correlation matrix of a dataset using a heatmap")
plt.show()
